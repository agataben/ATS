# %%
from ats.dataset_generators import SynteticHumiTempDatasetGenerator
from ats.synthetic_data import plot_func

# Inizialize
generator = SynteticHumiTempDatasetGenerator()

# %% 
# --- Test generate_test_dataset ---

test_dataset = generator.generate( 
    n = 9,
    plot = True,
    effects = ['noise','clouds'],
    anomalies = [ 'step_mv', 'clouds','step_uv']

)
print(f"Test dataset: {len(test_dataset)} series")
# Plotta each series 
#or i, df in enumerate(test_dataset):
 #   print(f"Plotting series {i+1}")
  #  plot_func(df) 
    #print(df)
# Out:
# Test dataset: 9 series
