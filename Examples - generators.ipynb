# %%
from ats.generators import HumiTempEvaluationDataGenerator
from ats.synthetic_data import plot_func

# Inizialize
generator = HumiTempEvaluationDataGenerator()

# --- Test generate_reference_dataset ---
reference_dataset = generator.generate_reference_dataset(
    n=5,
    effects=['noise', 'seasons'],
    random_effects=['clouds']
)
print(f"Reference dataset: {len(reference_dataset)} series")

#print(reference_dataset)

# Plot each series 
for i, df in enumerate(reference_dataset):
    print(f"Plotting series {i}")
    plot_func(df.reset_index())
# Out:
# Reference dataset: 5 series
# Plotting series 0
# Plotting series 1
# Plotting series 2
# Plotting series 3
# Plotting series 4

# %%
# %% 
# --- Test generate_test_dataset ---
howmany_test = 9
test_dataset = generator.generate_test_dataset(
    howmany_series=howmany_test
)
# Plotta each series 
for i, df in enumerate(test_dataset):
    print(f"Plotting series {i}")
    plot_func(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # %%
#       2 # --- Test generate_test_dataset ---
#       3 howmany_test = 9
# ----> 4 test_dataset = generator.generate_test_dataset(
#       5     howmany_series=howmany_test
#       6 )
#       7 # Plotta each series
#       8 for i, df in enumerate(test_dataset):
#
# TypeError: generate_test_dataset() got an unexpected keyword argument 'howmany_series'
