# %%
from ats import logger
logger.setup('INFO')

# %%
from ats.utils import generate_timeseries_df, plot_timeseries_df

# %%
univariate_timeseries_df = generate_timeseries_df()
multivariate_timeseries_df = generate_timeseries_df(variables=2)

# %%
univariate_timeseries_df
# Out:
#                               value
# timestamp
# 2025-06-10 14:00:00+00:00  0.000000
# 2025-06-10 15:00:00+00:00  0.841471
# 2025-06-10 16:00:00+00:00  0.909297
# 2025-06-10 17:00:00+00:00  0.141120
# 2025-06-10 18:00:00+00:00 -0.756802
# 2025-06-10 19:00:00+00:00 -0.958924
# 2025-06-10 20:00:00+00:00 -0.279415
# 2025-06-10 21:00:00+00:00  0.656987
# 2025-06-10 22:00:00+00:00  0.989358
# 2025-06-10 23:00:00+00:00  0.412118

# %%
plot_timeseries_df(univariate_timeseries_df, image=True)

# %%
multivariate_timeseries_df
# Out:
#                             value_1   value_2
# timestamp
# 2025-06-10 14:00:00+00:00  0.000000  0.707107
# 2025-06-10 15:00:00+00:00  0.841471  0.977061
# 2025-06-10 16:00:00+00:00  0.909297  0.348710
# 2025-06-10 17:00:00+00:00  0.141120 -0.600243
# 2025-06-10 18:00:00+00:00 -0.756802 -0.997336
# 2025-06-10 19:00:00+00:00 -0.958924 -0.477482
# 2025-06-10 20:00:00+00:00 -0.279415  0.481366
# 2025-06-10 21:00:00+00:00  0.656987  0.997649
# 2025-06-10 22:00:00+00:00  0.989358  0.596698
# 2025-06-10 23:00:00+00:00  0.412118 -0.352855

# %%
plot_timeseries_df(multivariate_timeseries_df, image=True)
